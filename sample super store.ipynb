# %% [markdown]
# Define the data
#
# collect the data
#
# clean the data
#
# analyze the data

# %% [markdown]
# # import the libraries in python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("dark_background")
import warnings
warnings.filterwarnings("ignore")
from datetime import datetime
import os
sns.set(color_codes=True)

# %% [markdown]
# #import the Anvironment

# %% [markdown]
# DATASETS : https://www.kaggle.com/datasets/bravehart101/sample-supermarket-dataset

# %%
df=pd.read_csv("/content/drive/MyDrive/project_file/SampleSuperstore.csv.zip")
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# # Check the basic structure

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
for i in df.columns:
  print(i)
# Out:
# Ship Mode
# Segment
# Country
# City
# State
# Postal Code
# Region
# Category
# Sub-Category
# Sales
# Quantity
# Discount
# Profit

# %%
df.sample()
# Out:
#         Ship Mode   Segment        Country         City       State  \
# 2888  First Class  Consumer  United States  Los Angeles  California
#
#       Postal Code Region         Category Sub-Category  Sales  Quantity  \
# 2888        90008   West  Office Supplies        Paper   32.4         5
#
#       Discount  Profit
# 2888       0.0  15.552

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# # Check the duplicate value

# %%
df.duplicated().sum()
# Out:
# 17

# %% [markdown]
# # Drop duplicate values

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# #Recheck duplicate values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # check the columns

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# # check unique values

# %%
df["Profit"].unique()
# Out:
# array([ 41.9136, 219.582 ,   6.8714, ...,  16.124 ,   4.1028,  72.948 ])

# %%
df["Country"]
# Out:
# 0       United States
# 1       United States
# 2       United States
# 3       United States
# 4       United States
#             ...
# 9989    United States
# 9990    United States
# 9991    United States
# 9992    United States
# 9993    United States
# Name: Country, Length: 9977, dtype: object

# %%
df["State"].unique()
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %% [markdown]
# # check the statistical values

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount      Profit
# count   9977.000000   9977.000000  9977.000000  9977.000000  9977.00000
# mean   55154.964117    230.148902     3.790719     0.156278    28.69013
# std    32058.266816    623.721409     2.226657     0.206455   234.45784
# min     1040.000000      0.444000     1.000000     0.000000 -6599.97800
# 25%    23223.000000     17.300000     2.000000     0.000000     1.72620
# 50%    55901.000000     54.816000     3.000000     0.200000     8.67100
# 75%    90008.000000    209.970000     5.000000     0.200000    29.37200
# max    99301.000000  22638.480000    14.000000     0.800000  8399.97600

# %% [markdown]
# # check null values

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#percent_missing_value=df.isnull().sum()*100/len(df)
#percent_missing_value

# %%
df["Ship Mode"]
# Out:
# 0         Second Class
# 1         Second Class
# 2         Second Class
# 3       Standard Class
# 4       Standard Class
#              ...
# 9989      Second Class
# 9990    Standard Class
# 9991    Standard Class
# 9992    Standard Class
# 9993      Second Class
# Name: Ship Mode, Length: 9977, dtype: object

# %%
df["Segment"]
# Out:
# 0        Consumer
# 1        Consumer
# 2       Corporate
# 3        Consumer
# 4        Consumer
#           ...
# 9989     Consumer
# 9990     Consumer
# 9991     Consumer
# 9992     Consumer
# 9993     Consumer
# Name: Segment, Length: 9977, dtype: object

# %%
df["Ship Mode"].value_counts()
# Out:
# Ship Mode
# Standard Class    5955
# Second Class      1943
# First Class       1537
# Same Day           542
# Name: count, dtype: int64

# %%
df[0:6]
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
# ...

# %%
category_counts = df['Category'].value_counts()
plt.pie(category_counts, labels=category_counts.index, autopct="%0.2f%%")
plt.show()

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
s=df.Category.value_counts()
s
# Out:
# Category
# Office Supplies    6012
# Furniture          2118
# Technology         1847
# Name: count, dtype: int64

# %%
s.plot(kind='barh')
plt.show()

# %%
s.plot(kind='pie',autopct="%0.2f%%")
plt.show()

# %%
h=df["Ship Mode"].value_counts()
h
# Out:
# Ship Mode
# Standard Class    5955
# Second Class      1943
# First Class       1537
# Same Day           542
# Name: count, dtype: int64

# %%
h.plot(kind='pie',autopct="%0.2f%%")
plt.show()

# %%
plt.figure(figsize=(15,10))
gf=sns.countplot(x='Ship Mode',data=df)
gf.bar_label(gf.containers[0])
plt.show()

# %%
c=df['Category'].value_counts()
c
# Out:
# Category
# Office Supplies    6012
# Furniture          2118
# Technology         1847
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,10))
gf=sns.countplot(x='Category',data=df)
gf.bar_label(gf.containers[0])
plt.show()

# %% [markdown]
# How can you filter rows in the DataFrame df where:
#
# The Category is "Office Supplies", and
# The Sales are greater than 10?

# %%
# Assuming 'Sales' column contains the numerical values you're interested in
df[(df['Category'] == 'Office Supplies') & (df['Sales'] > 10)]
# Out:
#            Ship Mode    Segment        Country             City  \
# 2       Second Class  Corporate  United States      Los Angeles
# 4     Standard Class   Consumer  United States  Fort Lauderdale
# 8     Standard Class   Consumer  United States      Los Angeles
# 9     Standard Class   Consumer  United States      Los Angeles
# 12    Standard Class   Consumer  United States          Concord
# ...              ...        ...            ...              ...
# 9982  Standard Class   Consumer  United States     Grand Rapids
# 9984  Standard Class   Consumer  United States       Long Beach
# 9985  Standard Class   Consumer  United States       Long Beach
# 9992  Standard Class   Consumer  United States       Costa Mesa
# 9993    Second Class   Consumer  United States      Westminster
#
#                State  Postal Code   Region         Category Sub-Category  \
# 2         California        90036     West  Office Supplies       Labels
# ...

# %%
df["Sales"].sort_values(ascending=True).head(5)
# Out:
# 4101    0.444
# 9292    0.556
# 8658    0.836
# 4711    0.852
# 2106    0.876
# Name: Sales, dtype: float64

# %% [markdown]
# How can you calculate the sum of Sales for each unique value in the Sub-Category column in the DataFrame df and display the first 7 results?

# %%
h=df.groupby("Sub-Category")["Sales"].sum().head(7)
h
# Out:
# Sub-Category
# Accessories    167380.3180
# Appliances     107532.1610
# Art             27107.0320
# Binders        203409.1690
# Bookcases      114879.9963
# Chairs         327777.7610
# Copiers        149528.0300
# Name: Sales, dtype: float64

# %%
h=df.groupby("Sub-Category")["Sales"].sum().head(7).plot(kind='pie',autopct="%0.2f%%")
h
# Out:
# <Axes: ylabel='Sales'>

# %%
h.plot(kind='pie',autopct="%0.2f%%")
plt.show()

# %%
sns.displot(df["Category"])
plt.show()

# %% [markdown]
# How can you filter rows in the DataFrame df where:
#
# The State is "New York", and
# The Sales is equal to 31.500?

# %%
df[(df["State"]=='New York')&(df['Sales']==31.500)]
# Out:
#            Ship Mode   Segment        Country        City     State  \
# 9984  Standard Class  Consumer  United States  Long Beach  New York
#
#       Postal Code Region         Category Sub-Category  Sales  Quantity  \
# 9984        11561   East  Office Supplies       Labels   31.5        10
#
#       Discount  Profit
# 9984       0.0   15.12

# %%
df.groupby("Region").Sales.count().plot(kind='pie',autopct="%0.2f%%")
plt.show()

# %%
df['Sub-Category']
# Out:
# 0         Bookcases
# 1            Chairs
# 2            Labels
# 3            Tables
# 4           Storage
#            ...
# 9989    Furnishings
# 9990    Furnishings
# 9991         Phones
# 9992          Paper
# 9993     Appliances
# Name: Sub-Category, Length: 9977, dtype: object

# %%
len(df[df["Sub-Category"].str.contains("Paper")])
# Out:
# 1359

# %%
df[df["Sub-Category"].str.contains("Phones")].count()
# Out:
# Ship Mode       889
# Segment         889
# Country         889
# City            889
# State           889
# Postal Code     889
# Region          889
# Category        889
# Sub-Category    889
# Sales           889
# Quantity        889
# Discount        889
# Profit          889
# dtype: int64

# %%
df[df["Category"].max()==df["Category"]]["Sub-Category"]
# Out:
# 7            Phones
# 11           Phones
# 19           Phones
# 26      Accessories
# 35           Phones
#            ...
# 9983         Phones
# 9986    Accessories
# 9987    Accessories
# 9988         Phones
# 9991         Phones
# Name: Sub-Category, Length: 1847, dtype: object

# %%
df[df["Category"].min()==df["Category"]]["Sub-Category"]
# Out:
# 0         Bookcases
# 1            Chairs
# 3            Tables
# 5       Furnishings
# 10           Tables
#            ...
# 9962      Bookcases
# 9964    Furnishings
# 9980         Tables
# 9989    Furnishings
# 9990    Furnishings
# Name: Sub-Category, Length: 2118, dtype: object

# %% [markdown]
# Q 1: What is the total profit generated?

# %%
total_profit = df["Profit"].sum()
print(f"Total profit generated: ${total_profit:.2f}")
# Out:
# Total profit generated: $286241.42

# %% [markdown]
# Q 2: Which product category contributed the most to total sales?

# %%
top_category = df.groupby("Category")["Sales"].sum().idxmax()
category_sales = df.groupby("Category")["Sales"].sum().max()
print(f"Category with highest sales: {top_category} (${category_sales:.2f})")
# Out:
# Category with highest sales: Technology ($836154.03)

# %% [markdown]
# Q 3: What is the average discount offered across all orders?

# %%
average_discount = df["Discount"].mean()
print(f"Average discount offered: {average_discount:.2%}")
# Out:
# Average discount offered: 15.63%

# %% [markdown]
# Q 4: Which ship mode is the most commonly used?

# %%
# Assuming your dataframe is named df
ship_mode_counts = df['Ship Mode'].value_counts()

# Get the most commonly used ship mode
most_common_ship_mode = ship_mode_counts.idxmax()
print(f"The most commonly used ship mode is: {most_common_ship_mode}")
# Out:
# The most commonly used ship mode is: Standard Class
